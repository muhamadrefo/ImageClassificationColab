# %% [markdown]
# <a href="https://colab.research.google.com/github/muhamadrefo/ImageClassificationColab/blob/master/SVM6_v2_4_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importing Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from datetime import datetime
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, precision_recall_fscore_support
from sklearn.metrics import confusion_matrix as cm
from sklearn import model_selection
from sklearn.model_selection import train_test_split as tt, GridSearchCV
from sklearn.metrics import classification_report
# %matplotlib inline

# %cd /content/drive/My Drive/Batik/SVM/
# %ls
# Out:
# /content/drive/My Drive/Batik/SVM
# BatikYogya/         nama_file.csv          RsGauss.csv    RsPolynomial.csv
# DataGaussian.csv    newDataTraining.csv    RsLinear2.csv  RsSigmoid.csv
# DataTraining.csv    newDataValidation.csv  RsLinear3.csv  RsTryLinear2.csv
# DataValidation.csv  PrecisionTryLin.csv    RsLinear.csv

# %%
dTrain = pd.read_csv('newDataTraining.csv')
dValid = pd.read_csv('newDataTraining.csv')
x = dTrain.iloc[:, 1:6].values
y = dTrain.iloc[:, 7].values
valDat = dValid.iloc[:, 1:6].values
valTarget = dValid.iloc[:, 7].values
Rans = 100

# %%
def linear():
  startTime = datetime.now()
  model = SVC(kernel='linear')
  with open('RsLinear.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['RandomState', 'Accuracy Training', 'Accuracy Validation'])
    for rs in range(int(Rans)):
      x_train, x_test, y_train, y_test = tt(x,y, test_size=0.2, random_state=rs+1)
      model.fit(x_train, y_train)
      y_pred = model.predict(x_test)
      valPred = model.predict(valDat)
      accT = (np.sum(y_pred == y_test)/ y_test.size)*100
      accV = (np.sum(valPred == valTarget)/ valTarget.size)*100
      writer.writerow([str(rs+1),str(accT),str(accV)])
  print('Time Processing  : ', (datetime.now()-startTime))

linear()
showLin = pd.read_csv('RsLinear.csv')
showLin
# Out:
# Time Processing  :  0:00:00.647558
#     RandomState  Accuracy Training  Accuracy Validation
# 0             1          57.407407            62.686567
# 1             2          51.851852            57.835821
# 2             3          61.111111            60.261194
# 3             4          51.851852            57.462687
# 4             5          58.333333            59.141791
# ..          ...                ...                  ...
# 95           96          56.481481            60.261194
# 96           97          64.814815            60.634328
# 97           98          59.259259            59.328358
# 98           99          63.888889            60.634328
# 99          100          63.888889            60.447761
#
# [100 rows x 3 columns]

# %%
def sigmoid():
  startTime = datetime.now()
  model = SVC(kernel='sigmoid')
  with open('RsSigmoid.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['RandomState', 'Accuracy Training', 'Accuracy Validation'])
    for rs in range(int(Rans)):
      x_train, x_test, y_train, y_test = tt(x,y, test_size=0.2, random_state=rs+1)
      model.fit(x_train, y_train)
      y_pred = model.predict(x_test)
      valPred = model.predict(valDat)
      accT = (np.sum(y_pred == y_test)/ y_test.size)*100
      accV = (np.sum(valPred == valTarget)/ valTarget.size)*100
      writer.writerow([str(rs+1),str(accT),str(accV)])
  print('Time Processing  : ', (datetime.now()-startTime))

sigmoid()
showSig = pd.read_csv('RsSigmoid.csv')
showSig
# Out:
# Time Processing  :  0:00:02.354393
#     RandomState  Accuracy Training  Accuracy Validation
# 0             1          54.629630            51.865672
# 1             2          50.000000            51.865672
# 2             3          44.444444            51.865672
# 3             4          52.777778            51.865672
# 4             5          37.962963            48.134328
# ..          ...                ...                  ...
# 95           96          50.000000            51.865672
# 96           97          45.370370            51.865672
# 97           98          53.703704            51.865672
# 98           99          48.148148            51.865672
# 99          100          48.148148            51.865672
#
# [100 rows x 3 columns]

# %%
def gaussian():
  startTime = datetime.now()
  model = SVC(kernel='rbf')
  with open('RsGauss.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['RandomState', 'Accuracy Training', 'Accuracy Validation'])
    for rs in range(int(Rans)):
      x_train, x_test, y_train, y_test = tt(x,y, test_size=0.2, random_state=rs+1)
      model.fit(x_train, y_train)
      y_pred = model.predict(x_test)
      valPred = model.predict(valDat)
      accT = (np.sum(y_pred == y_test)/ y_test.size)*100
      accV = (np.sum(valPred == valTarget)/ valTarget.size)*100
      writer.writerow([str(rs+1),str(accT),str(accV)])
  print('Time Processing  : ', (datetime.now()-startTime))

gaussian()
showrbf = pd.read_csv('RsGauss.csv')
showrbf
# Out:
# Time Processing  :  0:00:01.148427
#     RandomState  Accuracy Training  Accuracy Validation
# 0             1          78.703704            82.835821
# 1             2          83.333333            83.022388
# 2             3          84.259259            83.582090
# 3             4          79.629630            83.395522
# 4             5          83.333333            82.276119
# ..          ...                ...                  ...
# 95           96          80.555556            83.022388
# 96           97          90.740741            84.141791
# 97           98          78.703704            83.395522
# 98           99          88.888889            83.582090
# 99          100          86.111111            83.582090
#
# [100 rows x 3 columns]

# %%
def poly():
  startTime = datetime.now()
  model = SVC(kernel='poly')
  with open('RsPolynomial.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['RandomState', 'Accuracy Training', 'Accuracy Validation'])
    for rs in range(int(Rans)):
      x_train, x_test, y_train, y_test = tt(x,y, test_size=0.2, random_state=rs+1)
      model.fit(x_train, y_train)
      y_pred = model.predict(x_test)
      valPred = model.predict(valDat)
      accT = (np.sum(y_pred == y_test)/ y_test.size)*100
      accV = (np.sum(valPred == valTarget)/ valTarget.size)*100
      writer.writerow([str(rs+1),str(accT),str(accV)])
  print('Time Processing  : ', (datetime.now()-startTime))

poly()
showPoly = pd.read_csv('RsPolynomial.csv')
showPoly
# Out:
# Time Processing  :  0:00:00.912026
#     RandomState  Accuracy Training  Accuracy Validation
# 0             1          82.407407            84.514925
# 1             2          85.185185            83.582090
# 2             3          85.185185            83.955224
# 3             4          79.629630            83.208955
# 4             5          84.259259            83.582090
# ..          ...                ...                  ...
# 95           96          79.629630            84.141791
# 96           97          90.740741            84.141791
# 97           98          79.629630            84.141791
# 98           99          87.962963            83.582090
# 99          100          84.259259            83.582090
#
# [100 rows x 3 columns]

# %% [markdown]
# #Incomplete Task

# %%
def pandas_classification_report(y_true, y_pred):
        metrics_summary = precision_recall_fscore_support(
                y_true=y_true, 
                y_pred=y_pred)

        avg = list(precision_recall_fscore_support(
                y_true=y_true, 
                y_pred=y_pred,
                average='weighted'))

        metrics_sum_index = ['precision', 'recall', 'f1-score', 'support']

        class_report_df = pd.DataFrame(list(metrics_summary),index=metrics_sum_index)
        support = class_report_df.loc['support']
        total = support.sum() 
        avg[-1] = total
        
        # class_report_df = pd.DataFrame(index=metrics_sum_index)
        class_report_df['avg / total'] = avg

        return class_report_df.T

def linear2():
  startTime = datetime.now()
  model = SVC(kernel='linear')
  with open('RsLinear2.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['RandomState', 'Accuracy Training', 'Accuracy Validation', 'Clas Report'])
    for rs in range(int(Rans)):
      x_train, x_test, y_train, y_test = tt(x,y, test_size=0.2, random_state=rs+1)
      model.fit(x_train, y_train)
      y_pred = model.predict(x_test)
      valPred = model.predict(valDat)
      accT = (np.sum(y_pred == y_test)/ y_test.size)*100
      accV = (np.sum(valPred == valTarget)/ valTarget.size)*100
      cls_rpt = classification_report(y_test, y_pred)
      class_report = pandas_classification_report(valTarget, valPred)
      writer.writerow([str(rs+1),str(accT),str(accV), str(cls_rpt)])

  class_report.to_csv('RsTryLinear2.csv', header=True)
  print('Time Processing  : ', (datetime.now()-startTime))

linear2()
showLin2 = pd.read_csv('RsLinear2.csv')
showLin2
# Out:
# Time Processing  :  0:00:01.165156
#     RandomState  ...                                        Clas Report
# 0             1  ...                precision    recall  f1-score   ...
# 1             2  ...                precision    recall  f1-score   ...
# 2             3  ...                precision    recall  f1-score   ...
# 3             4  ...                precision    recall  f1-score   ...
# 4             5  ...                precision    recall  f1-score   ...
# ..          ...  ...                                                ...
# 95           96  ...                precision    recall  f1-score   ...
# 96           97  ...                precision    recall  f1-score   ...
# 97           98  ...                precision    recall  f1-score   ...
# 98           99  ...                precision    recall  f1-score   ...
# 99          100  ...                precision    recall  f1-score   ...
#
# [100 rows x 4 columns]

# %%
showLin = pd.read_csv('RsTryLinear2.csv')
showLin
# Out:
#     Unnamed: 0  precision    recall  f1-score  support
# 0            0   0.683333  0.442446  0.537118    278.0
# 1            1   0.564607  0.779070  0.654723    258.0
# 2  avg / total   0.626185  0.604478  0.593726    536.0

# %%
def tryLin():
  startTime = datetime.now()
  model = SVC(kernel='linear')
  with open('RsLinear3.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['RandomState', 'Accuracy Training', 'Accuracy Validation', 'Class Report'])
    for rs in range(int(Rans)):
      x_train, x_test, y_train, y_test = tt(x,y, test_size=0.2, random_state=rs+1)
      model.fit(x_train, y_train)
      y_pred = model.predict(x_test)
      valPred = model.predict(valDat)
      accT = (np.sum(y_pred == y_test)/ y_test.size)*100
      accV = (np.sum(valPred == valTarget)/ valTarget.size)*100
      cls_rpt = classification_report(y_test, y_pred)
      writer.writerow([str(rs+1),str(accT),str(accV), str(cls_rpt)])
  print('Time Processing  : ', (datetime.now()-startTime))

tryLin()
showLin2 = pd.read_csv('RsLinear3.csv')
showLin2
# Out:
# Time Processing  :  0:00:01.179337
#     RandomState  ...                                       Class Report
# 0             1  ...                precision    recall  f1-score   ...
# 1             2  ...                precision    recall  f1-score   ...
# 2             3  ...                precision    recall  f1-score   ...
# 3             4  ...                precision    recall  f1-score   ...
# 4             5  ...                precision    recall  f1-score   ...
# ..          ...  ...                                                ...
# 95           96  ...                precision    recall  f1-score   ...
# 96           97  ...                precision    recall  f1-score   ...
# 97           98  ...                precision    recall  f1-score   ...
# 98           99  ...                precision    recall  f1-score   ...
# 99          100  ...                precision    recall  f1-score   ...
#
# [100 rows x 4 columns]
